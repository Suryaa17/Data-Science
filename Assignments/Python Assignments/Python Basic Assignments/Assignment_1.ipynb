# %% [markdown]
#                                                 ASSIGNMENT - 1

# %% [markdown]
# Name : NT SURYAA

# %% [markdown]
# 1) 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# *
#
# &#39;hello&#39;
#
# -87.8
#
# -
#
# /
#
# +
#
# 6

# %% [markdown]
# solution
#
# (*) - Expression
#
# ('hello') - value
#
# (-87.8) - value
#
# (-) - Expression
#
# (/) - Expression
#
# (+) - Expression
#
# (6) - Value

# %% [markdown]
# 2) What is the difference between string and variable?

# %% [markdown]
# Solution
#
# A string is a character datatype which is represented inside single or double qoutes. Whereas A variable is more like a empty box which is used to store some values of any datatype on it.
#
# Therefore, A string is a value/Data and variable is used to store that value on it.

# %% [markdown]
# 3)Describe three different data types.

# %% [markdown]
# The datatypes in python includes:
#
# Solution
#
# Numberical datatype - integer,float and complex values
#
# Boolean datatype
#
# String datatype
#
# List datatype
#
# Tuple datatype
#
# Dictionary datatype
#
# Set datatype

# %% [markdown]
# 4) What is an expression made up of? What do all expressions do?

# %% [markdown]
# Solution
#
# An expression made up of Variables,Operators and Operands.
#
# An expression can used to Evaluate values from the given expression.
#
# ex :- 10+20 = 30

# %% [markdown]
# 5) This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [markdown]
# Solution
#
# Spam = 10 is an assignment Statement as it assigns some value to a given variable.
#
# An expression is something which is used to evaluate something.
#
# An expression made up of Variables,Operators and Operands.
#
# An expression can used to Evaluate values from the given expression.
#
# ex :- 10+20 = 30
#
# Whereas, An statement wont evaluate to something or return any value.

# %% [markdown]
# 6) After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1

# %% [markdown]
# Solution
#
# bacon = 23
#
# (22+1 = 23)

# %% [markdown]
# 7) What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
#
# 'spam'*3

# %% [markdown]
# Solution
#
# 'spam' + 'spamspam' => 'spamspamspam'
#
# 'spam'*3 => 'spamspamspam'

# %% [markdown]
# 8)Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Solution
#
# eggs is a valid variable name because it satifies all the rules for naming a variable, Whereas 100 is not a proper variable name because it starts with a digit which is not a way to write a proper variable name (variables should not start with a digit).

# %% [markdown]
# 9)What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %% [markdown]
# Solution
#
# Integer => int()
#
# Float = > float()
#
# String => str()

# %% [markdown]
# 10)Why does this expression cause an error? How can you fix it?
#
# 'I have eaten' + 99 + 'burritos'

# %% [markdown]
# Solution
#
# It would cause an error because here in this code, 99 is an integer it should be converted into  an string before doing concatenation of the strings.
